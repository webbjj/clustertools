# %%
import nbodypy as npy
import matplotlib.pyplot as plt
import numpy as np

# %%
w0=[2.,4.,6.,8.]

# %%
cluster=[]
clabel=['W0=2','W0=4','W0=6','W0=8']
rm0=[]
phi0=[2.,4.,6.,8.]
cluster.append(npy.setup_cluster('king',N=10000,M=1000,rt=100,phi0=2.))
cluster.append(npy.setup_cluster('king',N=10000,M=1000,rt=100,phi0=4.))
cluster.append(npy.setup_cluster('king',N=10000,M=1000,rt=100,phi0=6.))
cluster.append(npy.setup_cluster('king',N=10000,M=1000,rt=100,phi0=8.))


for c in cluster:
    c.key_params()

    print(c.rm,c.mtot)
    rm0.append(c.rm)
# Out:
# 30.345469356866214 1000.0000000000002
# 22.824583604453952 1000.0000000000002
# 14.707291731051104 1000.0000000000002
# 10.456080883051936 1000.0000000000002

# %%
for i in range(0,len(cluster)):
    c=cluster[i]
    plt.plot(c.x,c.y,'o',alpha=0.5,label=clabel[i])

plt.legend()
plt.show()

# %%
for i in range(0,len(cluster)):
    c=cluster[i]
    kwargs={'label':clabel[i]}

    rprof,pprof,nprof=npy.rho_prof(c)        

    if i==0:
        npy.nlplot(rprof,pprof,log=True,label=clabel[i],xlabel='r \ (pc)',ylabel=r'$\rho \ (Msun/pc^3)$')
    else:
        npy.nlplot(rprof,pprof,log=True,label=clabel[i],overplot=True)
plt.legend()
plt.show()
plt.close()

# %%
dalpha=[0.,-0.5,-1.,-1.5]
alpha50=[-1.35,-1.,-0.65,-0.3]

da=np.empty((len(dalpha),len(alpha50),len(cluster)))
ag=np.empty((len(dalpha),len(alpha50),len(cluster)))
a50=np.empty((len(dalpha),len(alpha50),len(cluster)))

for i in range(0,len(dalpha)):
    for j in range(0,len(alpha50)):
        for k in range(0,len(phi0)):
            c=npy.setup_cluster('king',N=10000,M=1000,rt=100,phi0=phi0[k])  
            c.key_params()

            plt.close()
            print(dalpha[i],alpha50[j])
            c.m=npy.get_segregated_imf(c,dalpha[i],alpha50[j], mlimits = [0.1, 1.0],do_random=True)
            c.key_params()
            
            #rmrat=rm0[k]/c.rm
            #c.x*=rmrat
            #c.y*=rmrat
            #c.z*=rmrat
            #c.key_params()

            c.mass_function(0.1,1.,nmass=20,plot=True)
            plt.show()
            plt.close()
            
            c.alpha_prof(0.1,1.,nrad=20,nmass=20,plot=True)
            plt.show()
            plt.close()
            
            da[i,j,k]=c.dalpha
            ag[i,j,k]=c.alpha
            a50[i,j,k]=c.alpha50
# Out:
# 0.0 -1.35
# 1.1506848744920566 93.49316517705319 10000 10000
# 30.7055568132486 39.73350878143189 10000 1940
# 0.0 -1.35
# 0.7506867800799513 94.12594097865765 10000 10000
# 22.80395366357505 31.905490588927734 10000 2057
# 0.0 -1.35
# 0.37265286773868006 92.3721984667721 10000 10000
# 0.37265286773868006 92.3721984667721 10000 10000
# 13.042844336756065 20.159509016886144 10000 2005
# -0.5 -0.65
# 0.13215488645596754 92.43154908508215 10000 10000
# 8.016844446415966 15.53814995543083 10000 2091
# -0.5 -0.3
# 1.1506848744920566 93.49316517705319 10000 10000
# 29.11078925552456 38.057744430484966 10000 2013
# -0.5 -0.3
# 0.7506867800799513 94.12594097865765 10000 10000
# 21.438454597467146 30.022374308507427 10000 2082
# -0.5 -0.3
# 0.37265286773868006 92.3721984667721 10000 10000
# 13.257976661039288 20.510719860065503 10000 1994
# -0.5 -0.3
# 0.13215488645596754 92.43154908508215 10000 10000
# 8.288146986105906 15.938340825917743 10000 2082
# -1.0 -1.35
# 1.1506848744920566 93.49316517705319 10000 10000
# 27.14082166218801 35.77513875327052 10000 2076
# -1.0 -1.35
# 0.7506867800799513 94.12594097865765 10000 10000
# 19.328093425054558 27.124108159801953 10000 2115
# -1.0 -1.35
# 0.37265286773868006 92.3721984667721 10000 10000
# 11.26977775533269 17.66293966536108 10000 2047
# -1.0 -1.35
# 0.13215488645596754 92.43154908508215 10000 10000
# 6.0613964791129105 11.866447938041768 10000 1996
# -1.0 -1.0
# 1.1506848744920566 93.49316517705319 10000 10000
# 27.348977993024747 35.93601309938132 10000 2047
# -1.0 -1.0
# 0.7506867800799513 94.12594097865765 10000 10000
# 19.618838466766274 27.403442808746142 10000 2084
# -1.0 -1.0
# 0.37265286773868006 92.3721984667721 10000 10000
# 11.504423799727302 17.78703644626534 10000 2009
# -1.0 -1.0
# 0.13215488645596754 92.43154908508215 10000 10000
# 6.327138135966233 12.206990448269172 10000 1973
# -1.0 -0.65
# 1.1506848744920566 93.49316517705319 10000 10000
# 27.66982378301089 36.204315627012775 10000 2025
# -1.0 -0.65
# 0.7506867800799513 94.12594097865765 10000 10000
# 19.955341311015058 27.757268290923346 10000 2068
# -1.0 -0.65
# 0.37265286773868006 92.3721984667721 10000 10000
# 11.776233538969608 18.151603906259794 10000 1997
# -1.0 -0.65
# 0.13215488645596754 92.43154908508215 10000 10000
# 6.64168864925866 12.761052258899236 10000 1959
# -1.0 -0.3
# 1.1506848744920566 93.49316517705319 10000 10000
# 28.021179354720875 36.54850310870538 10000 2007
# -1.0 -0.3
# 0.7506867800799513 94.12594097865765 10000 10000
# 20.33027705985254 28.24644522350511 10000 2054
# -1.0 -0.3
# 0.37265286773868006 92.3721984667721 10000 10000
# 12.135707407175245 18.552100042171507 10000 1991
# -1.0 -0.3
# 0.13215488645596754 92.43154908508215 10000 10000
# 6.990437165869511 13.363760446369081 10000 1963
# -1.5 -1.35
# 1.1506848744920566 93.49316517705319 10000 10000
# 25.664427047788443 34.05675030991698 10000 2060
# -1.5 -1.35
# 0.7506867800799513 94.12594097865765 10000 10000
# 18.134066302203202 25.458614519544472 10000 2045
# -1.5 -1.35
# 0.37265286773868006 92.3721984667721 10000 10000
# 10.264718586906678 15.969590968900675 10000 2000
# -1.5 -1.35
# 0.13215488645596754 92.43154908508215 10000 10000
# 5.327842590419653 9.909562068446455 10000 1812
# -1.5 -1.0
# 1.1506848744920566 93.49316517705319 10000 10000
# 26.023470995659068 34.355229048006144 10000 2047
# -1.5 -1.0
# 0.7506867800799513 94.12594097865765 10000 10000
# 18.418909375300476 25.757785130012703 10000 2026
# -1.5 -1.0
# 0.37265286773868006 92.3721984667721 10000 10000
# 10.54827344341652 16.172911799312264 10000 1957
# -1.5 -1.0
# 0.13215488645596754 92.43154908508215 10000 10000
# 5.570752321730163 10.357892256263563 10000 1808
# -1.5 -0.65
# 1.1506848744920566 93.49316517705319 10000 10000
# 26.480875383976638 34.719532435570386 10000 2028
# -1.5 -0.65
# 0.7506867800799513 94.12594097865765 10000 10000
# 18.820402905066185 26.21628567366537 10000 2027
# -1.5 -0.65
# 0.37265286773868006 92.3721984667721 10000 10000
# 10.841052721393964 16.575972865886946 10000 1944
# -1.5 -0.65
# 0.13215488645596754 92.43154908508215 10000 10000
# 5.89648366297495 10.915671577463643 10000 1799
# -1.5 -0.3
# 1.1506848744920566 93.49316517705319 10000 10000
# 27.03427119397458 35.25869050308224 10000 2007
# -1.5 -0.3
# 0.7506867800799513 94.12594097865765 10000 10000
# 19.353511074292868 26.731653904448404 10000 2017
# -1.5 -0.3
# 0.37265286773868006 92.3721984667721 10000 10000
# 11.233729777339013 17.164047854464563 10000 1922
# -1.5 -0.3
# 0.13215488645596754 92.43154908508215 10000 10000
# 6.260133607256008 11.553719200646798 10000 1817

# %%
plt.figure(figsize=(10,10))
for k in range(0,len(cluster)):
    plt.subplot(2,2,k+1)

    for j in range(0,len(alpha50)):
        
        x=da[:,j,k]
        y=a50[:,j,k]/ag[:,j,k]

        plt.plot(x,y,label=r'$\alpha_{50} = %f$' % alpha50[j])
        
    if k==0:
        plt.legend()

    plt.ylim(0.5,1.5)
    plt.ylabel(r'$\alpha_{50}/\alpha$')
    plt.xlabel(r'$\delta_\alpha$')
    plt.gca().invert_xaxis()
    plt.title(clabel[k])

plt.show()
plt.close()

# %%
plt.figure(figsize=(10,10))
for i in range(0,len(dalpha)):
    plt.subplot(2,2,i+1)
    
    for j in range(0,len(alpha50)):
        
        x=w0
        y=ag[i,j,:]

        plt.plot(x,y,label=r'$\alpha_{50} = %f$' % alpha50[j])
        plt.plot(x,a50[i,j,:],'k--',alpha=0.5)

    if i==0:
        plt.legend()

    #plt.ylim(0,1.1)
    plt.ylabel(r'$\alpha_{global}$')
    plt.xlabel(r'$W_0$')
    plt.title(r'$\delta_\alpha$ = %f' % dalpha[i])

plt.show()
plt.close()
